# %% [markdown]
# # Mushroom classification in edible or poisonous
# ### UC Irvine Machine Learning Repository
#
# | Attribute                       | Classes                                                                                                      |
# |---------------------------------|--------------------------------------------------------------------------------------------------------------|
# | poisonous                       | e=edible, p=poisonous                                                                                        |
# | cap-shape                       | b=bell, c=conical, x=convex, f=flat, k=knobbed, s=sunken                                                     |
# | cap-surface                     | f=fibrous, g=grooves, y=scaly, s=smooth                                                                      |
# | cap-color                       | n=brown, b=buff, c=cinnamon, g=gray, r=green, p=pink, u=purple, e=red, w=white, y=yellow                     |
# | bruises?                        | t=bruises, f=no                                                                                              |
# | odor                            | a=almond, l=anise, c=creosote, y=fishy, f=foul, m=musty, n=none, p=pungent, s=spicy                          |
# | gill-attachment                 | a=attached, d=descending, f=free, n=notched                                                                  |
# | gill-spacing                    | c=close, w=crowded, d=distant                                                                                |
# | gill-size                       | b=broad, n=narrow                                                                                            |
# | gill-color                      | k=black, n=brown, b=buff, h=chocolate, g=gray, r=green, o=orange, p=pink, u=purple, e=red, w=white, y=yellow |
# | stalk-shape                     | e=enlarging, t=tapering                                                                                      |
# | stalk-root                      | b=bulbous, c=club, u=cup, e=equal, z=rhizomorphs, r=rooted, ?=missing                                        |
# | stalk-surface-above-ring        | f=fibrous, y=scaly, k=silky, s=smooth                                                                        |
# | stalk-surface-below-ring        | f=fibrous, y=scaly, k=silky, s=smooth                                                                        |
# | stalk-color-above-ring          | n=brown, b=buff, c=cinnamon, g=gray, o=orange, p=pink, e=red, w=white, y=yellow                              |
# | stalk-color-below-ring          | n=brown, b=buff, c=cinnamon, g=gray, o=orange, p=pink, e=red, w=white, y=yellow                              |
# | veil-type                       | p=partial, u=universal                                                                                       |
# | veil-color                      | n=brown, o=orange, w=white, y=yellow                                                                         |
# | ring-number                     | n=none, o=one, t=two                                                                                         |
# | ring-type                       | c=cobwebby, e=evanescent, f=flaring, l=large, n=none, p=pendant, s=sheathing, z=zone                         |
# | spore-print-color               | k=black, n=brown, b=buff, h=chocolate, r=green, o=orange, u=purple, w=white, y=yellow                        |
# | population                      | a=abundant, c=clustered, n=numerous, s=scattered, v=several, y=solitary                                      |
# | habitat                         | g=grasses, l=leaves, m=meadows, p=paths, u=urban, w=waste, d=woods                                           |

# %%
# %pip install pandas
# %pip install scikit-learn
# %pip install numpy
# %pip install matplotlib

# %%
# import warnings
# warnings.filterwarnings("ignore")

# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
# from sklearn.metrics import accuracy_score
# from sklearn.linear_model import LogisticRegression
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.naive_bayes import GaussianNB
# from sklearn.svm import SVC
# from sklearn.ensemble import (
#     BaggingClassifier, 
#     RandomForestClassifier, 
#     ExtraTreesClassifier, 
#     AdaBoostClassifier, 
#     GradientBoostingClassifier, 
#     VotingClassifier
# )

# %%
# # Reading data parameters
# FILE_PATH = 'agaricus-lepiota.data'
# DELIMITER = ','
# COLUMN_NAMES = [
#     'poisonous', 
#     'cap-shape', 
#     'cap-surface',
#     'cap-color',
#     'bruises',
#     'odor',
#     'gill-attachment',
#     'gill-spacing',
#     'gill-size',
#     'gill-color',
#     'stalk-shape',
#     'stalk-root',
#     'stalk-surface-above-ring',
#     'stalk-surface-below-ring',
#     'stalk-color-above-ring',
#     'stalk-color-below-ring',
#     'veil-type',
#     'veil-color',
#     'ring-number',
#     'ring-type',
#     'spore-print-color',
#     'population',
#     'habitat']

# %%
# df = pd.read_csv(
#     filepath_or_buffer=FILE_PATH, 
#     delimiter=DELIMITER, 
#     names=COLUMN_NAMES, 
#     header=None)

# %%
# df.head()

# %%
# df.info()

# %%
# # Constants
# TEST_SIZE = 0.20  # Proportion of the dataset to include in the test split
# SEED = 7          # Random seed for reproducibility

# # Separate features and target variable
# array = df.values
# X = array[:, :8]  # Features
# y = array[:, 8]   # Target variable

# # Split the dataset into training and test sets
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=TEST_SIZE,
#     shuffle=True,
#     random_state=SEED,
#     stratify=y
# )

# # Cross-validation parameters
# SCORING = 'accuracy'
# NUM_PARTITIONS = 10
# kfold = StratifiedKFold(
#     n_splits=NUM_PARTITIONS,
#     shuffle=True,
#     random_state=SEED
# )

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.linear_model import LogisticRegression
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.naive_bayes import GaussianNB
# from sklearn.svm import SVC
# from sklearn.ensemble import (
#     BaggingClassifier, 
#     RandomForestClassifier, 
#     ExtraTreesClassifier, 
#     AdaBoostClassifier, 
#     GradientBoostingClassifier, 
#     VotingClassifier
# )
# from sklearn.model_selection import cross_val_score, KFold
# from sklearn.preprocessing import LabelEncoder

# # Define global random seed
# np.random.seed(7)

# # Placeholder for X_train and y_train (replace this with actual data)
# # Example of categorical data:
# # X_train = [['p', 'x', 's', 's', 'f', 'c'], ... ]
# # y_train = ['n', 'n', 'b', ... ]

# # Encode categorical features in X_train
# X_encoded = np.array(X_train)
# y_encoded = np.array(y_train)

# label_encoder = LabelEncoder()

# # Apply label encoding to each column in X_train
# for i in range(X_encoded.shape[1]):
#     X_encoded[:, i] = label_encoder.fit_transform(X_encoded[:, i])

# # Encode target labels
# y_encoded = label_encoder.fit_transform(y_encoded)

# # Define cross-validation and scoring
# kfold = KFold(n_splits=10, shuffle=True, random_state=7)
# SCORING = 'accuracy'

# # Initialize list of models
# models = [
#     ('LR', LogisticRegression(max_iter=200)),
#     ('KNN', KNeighborsClassifier()),
#     ('CART', DecisionTreeClassifier()),
#     ('NB', GaussianNB()),
#     ('SVM', SVC())
# ]

# # Base classifier for BaggingClassifier
# base_classifier = DecisionTreeClassifier()
# num_trees = 100
# max_features = 3

# # Create models for VotingClassifier
# voting_models = [
#     ('logistic', LogisticRegression(max_iter=200)),
#     ('cart', DecisionTreeClassifier()),
#     ('svm', SVC())
# ]

# # Add ensemble models to the list
# models += [
#     ('Bagging', BaggingClassifier(estimator=base_classifier, n_estimators=num_trees)),
#     ('RF', RandomForestClassifier(n_estimators=num_trees, max_features=max_features)),
#     ('ET', ExtraTreesClassifier(n_estimators=num_trees, max_features=max_features)),
#     ('Ada', AdaBoostClassifier(n_estimators=num_trees)),
#     ('GB', GradientBoostingClassifier(n_estimators=num_trees)),
#     ('Voting', VotingClassifier(estimators=voting_models))
# ]

# # Lists to store results and model names
# results = []
# names = []

# # Train and evaluate models
# for name, model in models:
#     cv_results = cross_val_score(model, X_encoded, y_encoded, cv=kfold, scoring=SCORING)
#     results.append(cv_results)
#     names.append(name)
#     print(f"{name}: {cv_results.mean():.6f} ({cv_results.std():.6f})")

# # Boxplot to compare models
# plt.figure(figsize=(15, 10))
# plt.suptitle('Comparação dos Modelos')
# plt.boxplot(results)
# plt.xticks(range(1, len(names) + 1), names)
# plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import (
    BaggingClassifier, 
    RandomForestClassifier, 
    ExtraTreesClassifier, 
    AdaBoostClassifier, 
    GradientBoostingClassifier, 
    VotingClassifier
)

# Constants
FILE_PATH = 'agaricus-lepiota.data'
DELIMITER = ','
COLUMN_NAMES = [
    'poisonous', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 
    'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape',
    'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring',
    'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color',
    'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat'
]
TEST_SIZE = 0.20
SEED = 7
SCORING = 'accuracy'
NUM_PARTITIONS = 10


class ModelComparison:
    def __init__(self, file_path, delimiter, column_names, test_size, seed, num_partitions):
        self.file_path = file_path
        self.delimiter = delimiter
        self.column_names = column_names
        self.test_size = test_size
        self.seed = seed
        self.num_partitions = num_partitions
        self.models = []
        self.results = []
        self.names = []
        np.random.seed(self.seed)

    def load_data(self):
        """Load the dataset from the file."""
        df = pd.read_csv(self.file_path, delimiter=self.delimiter, names=self.column_names, header=None)
        return df

    def preprocess_data(self, df):
        """Preprocess the data by separating features and target, and encoding categorical data."""
        X = df.iloc[:, 1:].values  # Features (ignoring the 'poisonous' target column)
        y = df.iloc[:, 0].values   # Target ('poisonous')
        
        # Encode categorical features and target
        X_encoded = np.apply_along_axis(LabelEncoder().fit_transform, 0, X)
        y_encoded = LabelEncoder().fit_transform(y)

        return X_encoded, y_encoded

    def split_data(self, X, y):
        """Split the dataset into training and testing sets."""
        return train_test_split(X, y, test_size=self.test_size, shuffle=True, random_state=self.seed, stratify=y)

    def initialize_models(self):
        """Initialize a list of machine learning models and add them to the models list."""
        self.models = [
            ('LR', LogisticRegression(max_iter=200)),
            ('KNN', KNeighborsClassifier()),
            ('CART', DecisionTreeClassifier()),
            ('NB', GaussianNB()),
            ('SVM', SVC())
        ]

        base_classifier = DecisionTreeClassifier()
        num_trees = 100
        max_features = 3

        # Add ensemble models
        voting_models = [
            ('logistic', LogisticRegression(max_iter=200)),
            ('cart', DecisionTreeClassifier()),
            ('svm', SVC())
        ]

        self.models += [
            ('Bagging', BaggingClassifier(estimator=base_classifier, n_estimators=num_trees)),
            ('RF', RandomForestClassifier(n_estimators=num_trees, max_features=max_features)),
            ('ET', ExtraTreesClassifier(n_estimators=num_trees, max_features=max_features)),
            ('Ada', AdaBoostClassifier(n_estimators=num_trees)),
            ('GB', GradientBoostingClassifier(n_estimators=num_trees)),
            ('Voting', VotingClassifier(estimators=voting_models))
        ]

    def evaluate_models(self, X_train, y_train):
        """Evaluate the performance of each model using cross-validation."""
        kfold = StratifiedKFold(n_splits=self.num_partitions, shuffle=True, random_state=self.seed)
        
        for name, model in self.models:
            cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=SCORING)
            self.results.append(cv_results)
            self.names.append(name)
            print(f"{name}: {cv_results.mean():.6f} ({cv_results.std():.6f})")

    def plot_results(self):
        """Plot the results of model evaluation using a boxplot."""
        plt.figure(figsize=(15, 10))
        plt.suptitle('Model Comparison')
        plt.boxplot(self.results)
        plt.xticks(ticks=np.arange(1, len(self.names) + 1), labels=self.names)
        plt.show()

    def run(self):
        """Run the complete pipeline of data loading, preprocessing, model evaluation, and result plotting."""
        df = self.load_data()
        X_encoded, y_encoded = self.preprocess_data(df)
        X_train, X_test, y_train, y_test = self.split_data(X_encoded, y_encoded)

        self.initialize_models()
        self.evaluate_models(X_train, y_train)
        self.plot_results()


if __name__ == '__main__':
    model_comparison = ModelComparison(
        file_path=FILE_PATH, 
        delimiter=DELIMITER, 
        column_names=COLUMN_NAMES, 
        test_size=TEST_SIZE, 
        seed=SEED, 
        num_partitions=NUM_PARTITIONS
    )
    model_comparison.run()
# Out:
# LR: 0.948453 (0.005734)
# KNN: 0.998769 (0.001922)
# CART: 1.000000 (0.000000)
# NB: 0.921834 (0.011134)
# SVM: 0.988921 (0.003428)
# Bagging: 1.000000 (0.000000)
# RF: 1.000000 (0.000000)
# ET: 1.000000 (0.000000)
# Ada: 1.000000 (0.000000)
# GB: 0.999846 (0.000462)
# Voting: 0.989537 (0.003139)
